# %%
import pandas as pd

# Cargar los ficheros de balance
path_bal_general = "data/us-balance-quarterly.csv"
path_bal_banks = "data/us-balance-banks-quarterly.csv"
path_bal_insurance = "data/us-balance-insurance-quarterly.csv"

df_general = pd.read_csv(path_bal_general, sep=';')
df_banks = pd.read_csv(path_bal_banks, sep=';')
df_insurance = pd.read_csv(path_bal_insurance, sep=';')

df_general.shape, df_banks.shape, df_insurance.shape
# Out:
# ((47634, 30), (1783, 27), (733, 26))

# %%
print("Tickers en df general:",df_general['Ticker'].nunique())
print("Tickers en df banks:",df_banks['Ticker'].nunique())
print("Tickers en df insurance:",df_insurance['Ticker'].nunique())
# Out:
# Tickers en df general: 3627
# Tickers en df banks: 223
# Tickers en df insurance: 56

# %%
# Cargar Tickers del S&P 500
from src.funcionesExtract import limpieza_tickers, clean_ticker
path_sp500 = "data/constituents.csv" 
df_sp500 = pd.read_csv(path_sp500)
sp500_clean = limpieza_tickers(df_sp500)
tickers_sp = set(sp500_clean['Ticker'])

print("Tickers en S&P:", len(tickers_sp))
# Out:
# Tickers en S&P: 503

# %%
# Out:
# {'BRK-A', 'BRKHU', 'BRKR'}

# %%
# Out:
# {'BFAC', 'BFAM', 'BFLY', 'BFS'}

# %%
# Limpiar tickers y sets de valores unicos
df_general['Ticker_clean'] = df_general['Ticker'].map(clean_ticker)
df_banks['Ticker_clean'] = df_banks['Ticker'].map(clean_ticker)
df_insurance['Ticker_clean'] = df_insurance['Ticker'].map(clean_ticker)

tickers_general = set(df_general['Ticker_clean'].unique())
tickers_banks = set(df_banks['Ticker_clean'].unique())
tickers_insurance = set(df_insurance['Ticker_clean'].unique())

len(tickers_general), len(tickers_banks), len(tickers_insurance)
# Out:
# (3627, 223, 56)

# %%
# Verificar si hay tickers repetidos
len(tickers_general & tickers_banks), len(tickers_general & tickers_insurance), len(tickers_insurance & tickers_banks)
# Out:
# (0, 0, 0)

# %%
# Tickers del indice s&p en cada uno
len(tickers_general & tickers_sp), len(tickers_banks & tickers_sp), len(tickers_insurance & tickers_sp)
# Out:
# (360, 11, 13)

# %%
# Describe de fechas disponibles
df_general.groupby('Ticker_clean')['Fiscal Year'].nunique().describe()
# Out:
# count    3627.000000
# mean        4.259167
# std         1.920682
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         6.000000
# max         6.000000
# Name: Fiscal Year, dtype: float64

# %%
df_banks.groupby('Ticker_clean')['Fiscal Year'].nunique().describe()
# Out:
# count    223.000000
# mean       2.816143
# std        2.019569
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max        6.000000
# Name: Fiscal Year, dtype: float64

# %%
df_insurance.groupby('Ticker_clean')['Fiscal Year'].nunique().describe()
# Out:
# count    56.000000
# mean      4.339286
# std       2.020592
# min       1.000000
# 25%       2.000000
# 50%       6.000000
# 75%       6.000000
# max       6.000000
# Name: Fiscal Year, dtype: float64

# %%
# unir los 3 sets de tickers y ver missings con respecto al indice
tickers_simfin = tickers_general | tickers_banks | tickers_insurance
missing = sorted(tickers_sp - tickers_simfin)
missing[:], len(missing)
# Out:
# (['ADM',
#   'AES',
#   'AFL',
#   'AIG',
#   'AIZ',
#   'ALL',
#   'ALLE',
#   'AMT',
#   'AOS',
#   'APD',
#   'ARES',
#   'AXON',
#   'BDX',
#   'BF-B',
#   'BIIB',
#   'BNY',
#   'BRK-B',
#   'BRO',
#   'BXP',
#   'C',
#   'CARR',
#   'CCI',
#   'CEG',
#   'CFG',
#   'CLX',
#   'CMS',
#   'CNP',
#   'COP',
#   'COR',
#   'CPAY',
#   'CPB',
#   'CRH',
#   'DRI',
#   'EA',
#   'EG',
#   'EOG',
#   'EQT',
#   'ETR',
#   'EVRG',
#   'EXC',
#   'FDX',
#   'FDXF',
#   'FIS',
#   'FISV',
#   'FOXA',
#   'GEHC',
#   'GEV',
#   'GIS',
#   'GOOGL',
#   'GPN',
#   'HBAN',
#   'HCA',
#   'HII',
#   'HON',
#   'HSY',
#   'IBM',
#   'INTU',
#   'JNJ',
#   'KEY',
#   'KEYS',
#   'KHC',
#   'KIM',
#   'KKR',
#   'KMB',
#   'LDOS',
#   'LH',
#   'LNT',
#   'LYV',
#   'MAS',
#   'MCO',
#   'MO',
#   'MOS',
#   'MRSH',
#   'MS',
#   'MTB',
#   'NI',
#   'NWS',
#   'NWSA',
#   'O',
#   'ODFL',
#   'PAYX',
#   'PCAR',
#   'PEG',
#   'PFG',
#   'PGR',
#   'PNC',
#   'PPL',
#   'PRU',
#   'PSA',
#   'PSKY',
#   'Q',
#   'RCL',
#   'REG',
#   'RF',
#   'RJF',
#   'RMD',
#   'RVTY',
#   'SJM',
#   'SNA',
#   'SO',
#   'SOLV',
#   'SW',
#   'SYF',
#   'T',
#   'TKO',
#   'TPR',
#   'TROW',
#   'TXT',
#   'UDR',
#   'USB',
#   'VEEV',
#   'VLTO',
#   'VRSK',
#   'VTRS',
#   'WEC',
#   'WELL',
#   'WFC',
#   'XOM',
#   'XYZ'],
#  119)

# %%
# Busco BRK-B: Tickers que empiezan con "BRK" en general
tickers_brk = set(df_general[df_general['Ticker'].str.startswith('BRK', na=False)]['Ticker'])
tickers_brk
# Out:
# {'BRK-A', 'BRKHU', 'BRKR'}

# %%
# No va a estar en Banks ni en Insurance, pero lo busco igual
tickers_brk = set(df_banks[df_banks['Ticker'].str.startswith('BRK', na=False)]['Ticker'])
tickers_brk
# Out:
# {'BRKL'}

# %%
tickers_brk = set(df_insurance[df_insurance['Ticker'].str.startswith('BRK', na=False)]['Ticker'])
tickers_brk
# Out:
# set()

# %%
# Busco BF-B: Tickers que empiezan con "BF" en general
tickers_brk = set(df_general[df_general['Ticker'].str.startswith('BF', na=False)]['Ticker'])
tickers_brk
# Out:
# {'BFAC', 'BFAM', 'BFLY', 'BFS'}

# %%
tickers_brk = set(df_banks[df_banks['Ticker'].str.startswith('BF', na=False)]['Ticker'])
tickers_brk
# Out:
# {'BFC', 'BFST'}

# %%
tickers_brk = set(df_insurance[df_insurance['Ticker'].str.startswith('BF', na=False)]['Ticker'])
tickers_brk
# Out:
# set()

# %%
# Prueba de extraer_simfin()
import pandas as pd
from src.funcionesExtract import extraer_simfin
from src.funcionesExtract import limpieza_tickers
df_tickers = pd.read_csv('data/constituents.csv')

df_tickers_clean = limpieza_tickers(df_tickers)
tickers_list = df_tickers_clean["Ticker"].tolist()
df = extraer_simfin(tickers_list)
df.info()
# Out:
# Dataset "us-income-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
# Dataset "us-balance-quarterly" on disk (1 days old).
# - Loading from disk ... Done!
# Dataset "us-cashflow-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
# Dataset "us-income-banks-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
# Dataset "us-balance-banks-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
# Dataset "us-cashflow-banks-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
# Dataset "us-income-insurance-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
# Dataset "us-balance-insurance-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
# Dataset "us-cashflow-insurance-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
# <class 'pandas.core.frame.DataFrame'>
# Index: 6692 entries, 0 to 50229
# Data columns (total 82 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Ticker                                           6692 non-null   object
#  1   Report Date                                      6692 non-null   datetime64[ns]
#  2   SimFinId                                         6671 non-null   float64
#  3   Currency                                         6671 non-null   object
#  4   Fiscal Year                                      6671 non-null   float64
#  5   Fiscal Period                                    6671 non-null   object
#  6   Publish Date                                     6671 non-null   datetime64[ns]
#  7   Restated Date                                    6671 non-null   datetime64[ns]
#  8   Shares (Basic)                                   6666 non-null   float64
#  9   Shares (Diluted)                                 6668 non-null   float64
#  10  Revenue                                          6671 non-null   float64
#  11  Cost of Revenue                                  5967 non-null   float64
#  12  Gross Profit                                     5967 non-null   float64
#  13  Operating Expenses                               6257 non-null   float64
#  14  Selling, General & Administrative                5816 non-null   float64
#  15  Research & Development                           2623 non-null   float64
#  16  Depreciation & Amortization                      3073 non-null   float64
#  17  Operating Income (Loss)                          6671 non-null   float64
#  18  Non-Operating Income (Loss)                      6254 non-null   float64
#  19  Interest Expense, Net                            5559 non-null   float64
#  20  Pretax Income (Loss), Adj.                       6267 non-null   float64
#  21  Abnormal Gains (Losses)                          3484 non-null   float64
#  22  Pretax Income (Loss)                             6671 non-null   float64
#  23  Income Tax (Expense) Benefit, Net                6564 non-null   float64
#  24  Income (Loss) from Continuing Operations         6671 non-null   float64
#  25  Net Extraordinary Gains (Losses)                 516 non-null    float64
#  26  Net Income                                       6671 non-null   float64
#  27  Net Income (Common)                              6671 non-null   float64
#  28  Cash, Cash Equivalents & Short Term Investments  6655 non-null   float64
#  29  Accounts & Notes Receivable                      6003 non-null   float64
#  30  Inventories                                      4554 non-null   float64
#  31  Total Current Assets                             6269 non-null   float64
#  32  Property, Plant & Equipment, Net                 6263 non-null   float64
#  33  Long Term Investments & Receivables              2123 non-null   float64
#  34  Other Long Term Assets                           6269 non-null   float64
#  35  Total Noncurrent Assets                          6269 non-null   float64
#  36  Total Assets                                     6673 non-null   float64
#  37  Payables & Accruals                              6266 non-null   float64
#  38  Short Term Debt                                  4958 non-null   float64
#  39  Total Current Liabilities                        6269 non-null   float64
#  40  Long Term Debt                                   6211 non-null   float64
#  41  Total Noncurrent Liabilities                     6254 non-null   float64
#  42  Total Liabilities                                6673 non-null   float64
#  43  Share Capital & Additional Paid-In Capital       6539 non-null   float64
#  44  Treasury Stock                                   3689 non-null   float64
#  45  Retained Earnings                                6487 non-null   float64
#  46  Total Equity                                     6673 non-null   float64
#  47  Total Liabilities & Equity                       6673 non-null   float64
#  48  Net Income/Starting Line                         6585 non-null   float64
#  49  Non-Cash Items                                   6593 non-null   float64
#  50  Change in Working Capital                        6376 non-null   float64
#  51  Change in Accounts Receivable                    307 non-null    float64
#  52  Change in Inventories                            232 non-null    float64
#  53  Change in Accounts Payable                       269 non-null    float64
#  54  Change in Other                                  405 non-null    float64
#  55  Net Cash from Operating Activities               6673 non-null   float64
#  56  Change in Fixed Assets & Intangibles             6471 non-null   float64
#  57  Net Change in Long Term Investment               3233 non-null   float64
#  58  Net Cash from Acquisitions & Divestitures        3720 non-null   float64
#  59  Net Cash from Investing Activities               6673 non-null   float64
#  60  Dividends Paid                                   4894 non-null   float64
#  61  Cash from (Repayment of) Debt                    5821 non-null   float64
#  62  Cash from (Repurchase of) Equity                 5963 non-null   float64
#  63  Net Cash from Financing Activities               6666 non-null   float64
#  64  Net Change in Cash                               6673 non-null   float64
#  65  Provision for Loan Losses                        152 non-null    float64
#  66  Net Revenue after Provisions                     191 non-null    float64
#  67  Total Non-Interest Expense                       191 non-null    float64
#  68  Interbank Assets                                 112 non-null    float64
#  69  Short & Long Term Investments                    191 non-null    float64
#  70  Net Loans                                        167 non-null    float64
#  71  Net Fixed Assets                                 153 non-null    float64
#  72  Total Deposits                                   163 non-null    float64
#  73  Preferred Equity                                 173 non-null    float64
#  74  Net Change in Loans & Interbank                  172 non-null    float64
#  75  Effect of Foreign Exchange Rates                 271 non-null    float64
#  76  Total Claims & Losses                            173 non-null    float64
#  77  Income (Loss) from Affiliates, Net of Taxes      28 non-null     float64
#  78  Total Investments                                213 non-null    float64
#  79  Insurance Reserves                               193 non-null    float64
#  80  Policyholders Equity                             0 non-null      float64
#  81  Net Change in Investments                        213 non-null    float64
# dtypes: datetime64[ns](3), float64(76), object(3)
# memory usage: 4.2+ MB
